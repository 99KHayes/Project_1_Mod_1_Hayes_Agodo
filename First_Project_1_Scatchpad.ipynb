# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data Read In And Initial Inspection

# %%
bom_movie = pd.read_csv('data/bom.movie_gross.csv.gz')
print(bom_movie.info())
bom_movie.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB
# None
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
imdb_name_basics = pd.read_csv('data/imdb.name.basics.csv.gz')
print(imdb_name_basics.info())
imdb_name_basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
# nconst                606648 non-null object
# primary_name          606648 non-null object
# birth_year            82736 non-null float64
# death_year            6783 non-null float64
# primary_profession    555308 non-null object
# known_for_titles      576444 non-null object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB
# None
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# ...

# %%
imdb_title_akas = pd.read_csv('data/imdb.title.akas.csv.gz')
print(imdb_title_akas.info())
imdb_title_akas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
# title_id             331703 non-null object
# ordering             331703 non-null int64
# title                331703 non-null object
# region               278410 non-null object
# language             41715 non-null object
# types                168447 non-null object
# attributes           14925 non-null object
# is_original_title    331678 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB
# None
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
# ...

# %%
imdb_title_basics = pd.read_csv('data/imdb.title.basics.csv.gz')
print(imdb_title_basics.info())
imdb_title_basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB
# None
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# ...

# %%
imdb_title_crew = pd.read_csv('data/imdb.title.crew.csv.gz')
print(imdb_title_crew.info())
imdb_title_crew.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
# tconst       146144 non-null object
# directors    140417 non-null object
# writers      110261 non-null object
# dtypes: object(3)
# memory usage: 3.3+ MB
# None
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
imdb_title_principles = pd.read_csv('data/imdb.title.principals.csv.gz')
print(imdb_title_principles.info())
imdb_title_principles.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
# tconst        1028186 non-null object
# ordering      1028186 non-null int64
# nconst        1028186 non-null object
# category      1028186 non-null object
# job           177684 non-null object
# characters    393360 non-null object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB
# None
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
imdb_title_ratings = pd.read_csv('data/imdb.title.ratings.csv.gz')
print(imdb_title_ratings.info())
imdb_title_ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# None
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
rt_movie_info = pd.read_csv('data/rt.movie_info.tsv.gz', delimiter = '\t')
print(rt_movie_info.info())
rt_movie_info.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
# id              1560 non-null int64
# synopsis        1498 non-null object
# rating          1557 non-null object
# genre           1552 non-null object
# director        1361 non-null object
# writer          1111 non-null object
# theater_date    1201 non-null object
# dvd_date        1201 non-null object
# currency        340 non-null object
# box_office      340 non-null object
# runtime         1530 non-null object
# studio          494 non-null object
# dtypes: int64(1), object(11)
# memory usage: 146.3+ KB
# None
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# ...

# %%
rt_reviews = pd.read_csv('data/rt.reviews.tsv.gz', delimiter = '\t', encoding= 'unicode_escape')
print(rt_reviews.info())
rt_reviews.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
# id            54432 non-null int64
# review        48869 non-null object
# rating        40915 non-null object
# fresh         54432 non-null object
# critic        51710 non-null object
# top_critic    54432 non-null int64
# publisher     54123 non-null object
# date          54432 non-null object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB
# None
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# ...

# %%
tmdb_movies = pd.read_csv('data/tmdb.movies.csv.gz')
print(tmdb_movies.info())
tmdb_movies.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
# Unnamed: 0           26517 non-null int64
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB
# None
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# ...

# %%
tn_budgets = pd.read_csv('data/tn.movie_budgets.csv.gz')
print(tn_budgets.info())
tn_budgets.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.1+ KB
# None
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# ...

# %% [markdown]
# ## Bom Movie Set Studio Information

# %%
bom_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
bom_movie.head(15)
# Out:
#                                                 title studio  domestic_gross  \
# 0                                         Toy Story 3     BV     415000000.0
# 1                          Alice in Wonderland (2010)     BV     334200000.0
# 2         Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                           Inception     WB     292600000.0
# 4                                 Shrek Forever After   P/DW     238700000.0
# 5                          The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                          Iron Man 2   Par.     312400000.0
# 7                                             Tangled     BV     200800000.0
# 8                                       Despicable Me   Uni.     251500000.0
# 9                            How to Train Your Dragon   P/DW     217600000.0
# 10                         Clash of the Titans (2010)     WB     163200000.0
# ...

# %%
#drop the foreign gross column. Too many Null values and we onl really care about domestic
bom_movie_no_nulls = bom_movie.drop(columns='foreign_gross', axis =1, inplace=True)

# %%
bom_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 4 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 105.9+ KB

# %%
# Unique Studios 
 #3,382 movies and 258 studios
print(bom_movie.studio.unique())
print(len(bom_movie.studio.unique()))
# Out:
# ['BV' 'WB' 'P/DW' 'Sum.' 'Par.' 'Uni.' 'Fox' 'Wein.' 'Sony' 'FoxS' 'SGem'
#  'WB (NL)' 'LGF' 'MBox' 'CL' 'W/Dim.' 'CBS' 'Focus' 'MGM' 'Over.' 'Mira.'
#  'IFC' 'CJ' 'NM' 'SPC' 'ParV' 'Gold.' 'JS' 'RAtt.' 'Magn.' 'Free' '3D'
#  'UTV' 'Rela.' 'Zeit.' 'Anch.' 'PDA' 'Lorb.' 'App.' 'Drft.' 'Osci.' 'IW'
#  'Rog.' nan 'Eros' 'Relbig.' 'Viv.' 'Hann.' 'Strand' 'NGE' 'Scre.' 'Kino'
#  'Abr.' 'CZ' 'ATO' 'First' 'GK' 'FInd.' 'NFC' 'TFC' 'Pala.' 'Imag.' 'NAV'
#  'Arth.' 'CLS' 'Mont.' 'Olive' 'CGld' 'FOAK' 'IVP' 'Yash' 'ICir' 'FM'
#  'Vita.' 'WOW' 'Truly' 'Indic.' 'FD' 'Vari.' 'TriS' 'ORF' 'IM' 'Elev.'
#  'Cohen' 'NeoC' 'Jan.' 'MNE' 'Trib.' 'Rocket' 'OMNI/FSR' 'KKM' 'Argo.'
#  'SMod' 'Libre' 'FRun' 'WHE' 'P4' 'KC' 'SD' 'AM' 'MPFT' 'Icar.' 'AGF'
#  'A23' 'Da.' 'NYer' 'Rialto' 'DF' 'KL' 'ALP' 'LG/S' 'WGUSA' 'MPI' 'RTWC'
#  'FIP' 'RF' 'ArcEnt' 'PalUni' 'EpicPics' 'EOne' 'LD' 'AF' 'TFA' 'Myr.'
#  'BM&DH' 'SEG' 'PalT' 'Outs' 'OutF' 'BSM' 'WAMCR' 'PM&E' 'A24' 'Cdgm.'
# ...

# %%
#Number of Movies per studio into a series
studio_counts = bom_movie.studio.value_counts()
top_studios = studio_counts.head(40)
studio_counts.head(3)
# Out:
# IFC     166
# Uni.    147
# WB      140
# Name: studio, dtype: int64

# %%
# Plot of the top 20 movie studios Matplotlib
top_studios.plot(title='Num of Films per Studio', kind='bar')

# %%
# Seaborn Official Plot of Number of Films Per Studio
ax = sns.barplot(top_studios.index, top_studios.values)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set_title('Number of Films per Studio from 2010 - 2018')
ax.set_xlabel('Studios')
ax.set_ylabel('Number of Films Produced')
plt.tight_layout()
plt.show()

# %%
bom_movie.head(5)
bom_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 4 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 105.9+ KB

# %%
bom_movie_no_nulls = bom_movie.copy()

# %%
# Drop null values in remaining rows
bom_movie_no_nulls.dropna(axis=0, inplace=True)

# %%
# Remove the year column, its not relevant to this specific analysis
bom_movie_no_nulls.drop(columns='year', inplace=True)

# %%
print(bom_movie_no_nulls.info())
bom_movie_no_nulls.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3356 entries, 0 to 3386
# Data columns (total 3 columns):
# title             3356 non-null object
# studio            3356 non-null object
# domestic_gross    3356 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 104.9+ KB
# None
#                                          title studio  domestic_gross
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0

# %%
# Get the average domestic budget for each studio and devide it by a million 
bom_movie_neatened = bom_movie_no_nulls.groupby('studio').mean() /1000000

# %%
#Rename column to reflect millions fraction
bom_movie_neatened.rename(columns={'domestic_gross': 'dom_gross_in_in_millions'})
print(bom_movie_neatened.head(3))
bom_movie_neatened.info()
# Out:
#         domestic_gross
# studio
# 3D            6.100000
# A23           0.082100
# A24           6.616208
# <class 'pandas.core.frame.DataFrame'>
# Index: 255 entries, 3D to Zeit.
# Data columns (total 1 columns):
# domestic_gross    255 non-null float64
# dtypes: float64(1)
# memory usage: 4.0+ KB

# %%
sorted_gross_studio = bom_movie_neatened.domestic_gross.sort_values(ascending = False)

# %%
top_gross = sorted_gross_studio.head(20)

# %%
# Seaborn Official Plot of Top 20 average Grossing Studios by Studio
ax = sns.barplot(top_gross.index, top_gross.values)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set_title('Top Average Gross by Studio 2010 - 2018')
ax.set_xlabel('Studios')
ax.set_ylabel('Gross Domestic in Millions')
#plt.tight_layout()
plt.show()

# %%
bom_movie_no_nulls.head()
# Out:
#                                          title studio  domestic_gross
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0

# %%
top_studios.head(4)
# Out:
# IFC     166
# Uni.    147
# WB      140
# Fox     136
# Name: studio, dtype: int64

# %%
# Create df with the gross product and with the number of movies per studio
new_bom_studios = pd.DataFrame([sorted_gross_studio, studio_counts])
#top_studios.join(top_gross, how='left')
new_bom_studios.head()
# Out:
#                         BV    P/DW    WB (NL)        Uni.          WB  \
# domestic_gross  173.764426  168.29  88.793333   87.771381   86.914614
# studio          106.000000   10.00  45.000000  147.000000  140.000000
#
#                        Fox        Sony       Par.        MGM       Sum.  ...  \
# domestic_gross   80.511029   77.611772   76.09773  66.666667  62.124733  ...
# studio          136.000000  110.000000  101.00000   3.000000  15.000000  ...
#
#                     KS     BSM    TAFC   Hiber     ALP  Shout!  Synergetic  \
# domestic_gross  0.0059  0.0051  0.0046  0.0036  0.0028  0.0028      0.0024
# studio          1.0000  1.0000  1.0000  1.0000  1.0000  3.0000      1.0000
#
#                     DR   PI  Myr.
# domestic_gross  0.0008  NaN   NaN
# studio          1.0000  1.0   1.0
#
# [2 rows x 257 columns]

# %%
transposed_bom = new_bom_studios.transpose()
transposed_bom.head(5)
# Out:
#          domestic_gross  studio
# BV           173.764426   106.0
# P/DW         168.290000    10.0
# WB (NL)       88.793333    45.0
# Uni.          87.771381   147.0
# WB            86.914614   140.0

# %%
transposed_bom['ratio'] = transposed_bom.domestic_gross / transposed_bom.studio
transposed_bom.head()
# Out:
#          domestic_gross  studio      ratio
# BV           173.764426   106.0   1.639287
# P/DW         168.290000    10.0  16.829000
# WB (NL)       88.793333    45.0   1.973185
# Uni.          87.771381   147.0   0.597084
# WB            86.914614   140.0   0.620819

# %%
transposed_ratio = transposed_bom.ratio.sort_values(ascending = False)
top_ratio = transposed_ratio.head(20)
top_ratio.head()
# Out:
# MGM         22.222222
# GrtIndia    20.200000
# P/DW        16.829000
# Studio 8    14.975000
# Mira.        7.019500
# Name: ratio, dtype: float64

# %%
# Seaborn Official Plot of Top 20 ratio of millions made per movie
ax = sns.barplot(top_ratio.index, top_ratio.values)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set_title('Top Ratio of million gross project per movie by Studio 2010 - 2018')
ax.set_xlabel('Studios')
ax.set_ylabel('Ratio of millions/movie')
plt.tight_layout()
plt.show()

# %%
# The most bang for your buck would be to work with MGM, GrtIndia, P/DW (paramount/Dream Works), or Studio 8. 
# For these studios you can expect to see an average of 17-ish million dollars profit per movie

# %%
transposed_bom.sort_values(['domestic_gross'],ascending = False)
# Out:
#             domestic_gross  studio      ratio
# BV              173.764426   106.0   1.639287
# P/DW            168.290000    10.0  16.829000
# WB (NL)          88.793333    45.0   1.973185
# Uni.             87.771381   147.0   0.597084
# WB               86.914614   140.0   0.620819
# Fox              80.511029   136.0   0.591993
# Sony             77.611772   110.0   0.705562
# Par.             76.097730   101.0   0.753443
# MGM              66.666667     3.0  22.222222
# Sum.             62.124733    15.0   4.141649
# LG/S             50.687805    41.0   1.236288
# SGem             43.611429    35.0   1.246041
# TriS             42.213043    23.0   1.835350
# LGF              40.381994   103.0   0.392058
# STX              31.337500    24.0   1.305729
# Studio 8         29.950000     2.0  14.975000
# FD               29.707429    14.0   2.121959
# Rela.            26.951257    35.0   0.770036
# W/Dim.           21.129823    14.0   1.509273
# ...

# %%
ratio_bom_df_top40 = transposed_bom.head(30)

# %%
#Seaborn Plot for Slide Deck with Studio Info

#Initialize Figure
f = plt.figure(figsize=(40,20))
ax1 = f.add_subplot(111)


# Set Up for first graph
#ax1 = sns.barplot(ratio_bom_df_top40.index, ratio_bom_df_top40.domestic_gross.values)
p1 = sns.scatterplot(ratio_bom_df_top40.index, ratio_bom_df_top40.domestic_gross.values, s = ratio_bom_df_top40.studio.values*65, label = '# of Movies Each Studio Produced', cmap='blues', color='Green', alpha=.5, edgecolors="black", linewidth=15, ax=ax1)
ax1.set_xticklabels(ratio_bom_df_top40.index, rotation=40, ha="right",fontsize=40)
ax1.set_yticklabels(list(range(0,200,20)) , fontsize=40)
ax1.set_title('Average Domestic Gross Profit in Millions by Studio 2010 - 2018', fontsize=60)
ax1.set_xlabel('Studios', fontsize=50)
ax1.set_ylabel('Millions of Dollars', fontsize=50)

for line in range(0,ratio_bom_df_top40.shape[0]):
     p1.text(ratio_bom_df_top40.index[line], ratio_bom_df_top40.domestic_gross.values[line], str(int(ratio_bom_df_top40.studio.values[line])), horizontalalignment='left', fontsize=30,  color='black', weight='semibold')
plt.legend(fontsize=50)      
plt.vlines(ratio_bom_df_top40.index, ymin=0, ymax=ratio_bom_df_top40.domestic_gross.values, label= "test")
#ax1.label()
plt.savefig('Lolipop_GDP.png')
plt.show()

# %% [markdown]
# ### New data explorations

# %%
# Lets make a giant IMDB data set and see what happens

# FIrst I will look at all the data sets to see what we are getting into

# %%
imdb_name_basics.head(5)
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
imdb_title_akas.head(5)
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
imdb_title_basics.head(5)
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_crew.head(5)
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
imdb_title_principles.head(5)
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
imdb_title_ratings.head(5)
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
imdb_title_akas = imdb_title_akas.set_index('title_id')
imdb_title_akas.head(3)
# Out:
#            ordering                                    title region language  \
# title_id
# tt0369610        10                            Джурасик свят     BG       bg
# tt0369610        11                        Jurashikku warudo     JP      NaN
# tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR      NaN
#
#                  types attributes  is_original_title
# title_id
# tt0369610          NaN        NaN                0.0
# tt0369610  imdbDisplay        NaN                0.0
# tt0369610  imdbDisplay        NaN                0.0

# %%
imdb_title_basics.rename(columns={'tconst': 'title_id'}, inplace=True)
imdb_title_basics = imdb_title_basics.set_index('title_id')
imdb_title_basics.head(3)
# Out:
#                              primary_title              original_title  \
# title_id
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
#
#            start_year  runtime_minutes              genres
# title_id
# tt0063540        2013            175.0  Action,Crime,Drama
# tt0066787        2019            114.0     Biography,Drama
# tt0069049        2018            122.0               Drama

# %%
imdb_title_crew.rename(columns={'tconst': 'title_id'}, inplace=True)
imdb_title_crew = imdb_title_crew.set_index('title_id')
imdb_title_crew.head(3)
# Out:
#            directors              writers
# title_id
# tt0285252  nm0899854            nm0899854
# tt0438973        NaN  nm0175726,nm1802864
# tt0462036  nm1940585            nm1940585

# %%
imdb_title_principles.rename(columns={'tconst': 'title_id'}, inplace=True)
imdb_title_principles = imdb_title_principles.set_index('title_id')
imdb_title_principles.head(3)
# Out:
#            ordering     nconst  category       job   characters
# title_id
# tt0111414         1  nm0246005     actor       NaN  ["The Man"]
# tt0111414         2  nm0398271  director       NaN          NaN
# tt0111414         3  nm3739909  producer  producer          NaN

# %%
imdb_title_ratings.rename(columns={'tconst': 'title_id'}, inplace=True)
imdb_title_ratings = imdb_title_ratings.set_index('title_id')
imdb_title_ratings.head(3)
# Out:
#             averagerating  numvotes
# title_id
# tt10356526            8.3        31
# tt10384606            8.9       559
# tt1042974             6.4        20

# %%
imdb_name_basics.rename(columns={'nconst': 'person_id'}, inplace=True)
imdb_name_basics = imdb_name_basics.set_index('person_id')
imdb_name_basics.head(3)
# Out:
#                 primary_name  birth_year  death_year  \
# person_id
# nm0061671  Mary Ellen Bauder         NaN         NaN
# nm0061865       Joseph Bauer         NaN         NaN
# nm0062070         Bruce Baum         NaN         NaN
#
#                                    primary_profession  \
# person_id
# nm0061671   miscellaneous,production_manager,producer
# nm0061865  composer,music_department,sound_department
# nm0062070                  miscellaneous,actor,writer
#
#                                   known_for_titles
# person_id
# nm0061671  tt0837562,tt2398241,tt0844471,tt0118553
# nm0061865  tt0896534,tt6791238,tt0287072,tt1682940
# nm0062070  tt1470654,tt0363631,tt0104030,tt0102898

# %%
# Now We can join them all together

# %%
step_1 = imdb_title_principles.join(imdb_title_basics, how='left', on ='title_id')
step_1.head(3)
# Out:
#            ordering     nconst  category       job   characters primary_title  \
# title_id
# tt0111414         1  nm0246005     actor       NaN  ["The Man"]   A Thin Life
# tt0111414         2  nm0398271  director       NaN          NaN   A Thin Life
# tt0111414         3  nm3739909  producer  producer          NaN   A Thin Life
#
#           original_title  start_year  runtime_minutes  genres
# title_id
# tt0111414    A Thin Life        2018             75.0  Comedy
# tt0111414    A Thin Life        2018             75.0  Comedy
# tt0111414    A Thin Life        2018             75.0  Comedy

# %%
step_2 = step_1.join(imdb_title_crew, how='left', on='title_id')
step_2.head(10)
# Out:
#            ordering     nconst  category       job                characters  \
# title_id
# tt0111414         1  nm0246005     actor       NaN               ["The Man"]
# tt0111414         2  nm0398271  director       NaN                       NaN
# tt0111414         3  nm3739909  producer  producer                       NaN
# tt0323808        10  nm0059247    editor       NaN                       NaN
# tt0323808         1  nm3579312   actress       NaN          ["Beth Boothby"]
# tt0323808         2  nm2694680     actor       NaN         ["Steve Thomson"]
# tt0323808         3  nm0574615     actor       NaN  ["Sir Lachlan Morrison"]
# tt0323808         4  nm0502652   actress       NaN   ["Lady Delia Morrison"]
# tt0323808         5  nm0362736  director       NaN                       NaN
# tt0323808         6  nm0811056  producer  producer                       NaN
#
#              primary_title   original_title  start_year  runtime_minutes  \
# title_id
# ...

# %%
step_3 = step_2.join(imdb_title_ratings, how='left', on='title_id')
step_3.head()
# Out:
#            ordering     nconst  category       job        characters  \
# title_id
# tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# tt0111414         2  nm0398271  director       NaN               NaN
# tt0111414         3  nm3739909  producer  producer               NaN
# tt0323808        10  nm0059247    editor       NaN               NaN
# tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]
#
#              primary_title   original_title  start_year  runtime_minutes  \
# title_id
# tt0111414      A Thin Life      A Thin Life        2018             75.0
# tt0111414      A Thin Life      A Thin Life        2018             75.0
# tt0111414      A Thin Life      A Thin Life        2018             75.0
# tt0323808  The Wicker Tree  The Wicker Tree        2011             96.0
# tt0323808  The Wicker Tree  The Wicker Tree        2011             96.0
#
#                  genres  directors    writers  averagerating  numvotes
# title_id
# ...

# %%
step_3.rename(columns={'nconst': 'person_id'})
# Out:
#            ordering   person_id         category       job  \
# title_id
# tt0111414         1   nm0246005            actor       NaN
# tt0111414         2   nm0398271         director       NaN
# tt0111414         3   nm3739909         producer  producer
# tt0323808        10   nm0059247           editor       NaN
# tt0323808         1   nm3579312          actress       NaN
# tt0323808         2   nm2694680            actor       NaN
# tt0323808         3   nm0574615            actor       NaN
# tt0323808         4   nm0502652          actress       NaN
# tt0323808         5   nm0362736         director       NaN
# tt0323808         6   nm0811056         producer  producer
# tt0323808         7   nm0914939         producer  producer
# tt0323808         8   nm0779346         composer       NaN
# tt0323808         9   nm0676104  cinematographer       NaN
# tt0417610        10   nm0284261         composer       NaN
# tt0417610         1   nm0532721            actor       NaN
# ...

# %%
# Now we have a big data set to work with!

final = step_3.join(imdb_name_basics, how='left', on='nconst')
final
# Out:
#            ordering      nconst         category       job  \
# title_id
# tt0111414         1   nm0246005            actor       NaN
# tt0111414         2   nm0398271         director       NaN
# tt0111414         3   nm3739909         producer  producer
# tt0323808        10   nm0059247           editor       NaN
# tt0323808         1   nm3579312          actress       NaN
# tt0323808         2   nm2694680            actor       NaN
# tt0323808         3   nm0574615            actor       NaN
# tt0323808         4   nm0502652          actress       NaN
# tt0323808         5   nm0362736         director       NaN
# tt0323808         6   nm0811056         producer  producer
# tt0323808         7   nm0914939         producer  producer
# tt0323808         8   nm0779346         composer       NaN
# tt0323808         9   nm0676104  cinematographer       NaN
# tt0417610        10   nm0284261         composer       NaN
# tt0417610         1   nm0532721            actor       NaN
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1028186 entries, tt0111414 to tt9692684
# Data columns (total 19 columns):
# ordering              1028186 non-null int64
# nconst                1028186 non-null object
# category              1028186 non-null object
# job                   177684 non-null object
# characters            393360 non-null object
# primary_title         1028186 non-null object
# original_title        1028186 non-null object
# start_year            1028186 non-null int64
# runtime_minutes       827933 non-null float64
# genres                1006451 non-null object
# directors             1014519 non-null object
# writers               860998 non-null object
# averagerating         629755 non-null float64
# numvotes              629755 non-null float64
# primary_name          1027912 non-null object
# birth_year            234048 non-null float64
# death_year            11843 non-null float64
# primary_profession    974266 non-null object
# ...

# %%
final.describe()
# Out:
#            ordering    start_year  runtime_minutes  averagerating  \
# count  1.028186e+06  1.028186e+06    827933.000000  629755.000000
# mean   4.739847e+00  2.014606e+03        90.406620       6.261820
# std    2.747446e+00  2.743153e+00       111.075051       1.451997
# min    1.000000e+00  2.010000e+03         1.000000       1.000000
# 25%    2.000000e+00  2.012000e+03        76.000000       5.400000
# 50%    4.000000e+00  2.015000e+03        90.000000       6.400000
# 75%    7.000000e+00  2.017000e+03       102.000000       7.300000
# max    1.000000e+01  2.115000e+03     51420.000000      10.000000
#
#            numvotes     birth_year   death_year
# count  6.297550e+05  234048.000000  11843.00000
# mean   4.109861e+03    1967.742617   1995.25247
# std    3.276328e+04      22.099106     64.57055
# min    5.000000e+00       1.000000     17.00000
# 25%    1.600000e+01    1959.000000   2004.00000
# 50%    6.500000e+01    1971.000000   2014.00000
# ...

# %%
plt.plot(final.numvotes.unique())

# %%
# Need to filter data for between 2010 - 2018 and average number of votes greater than the average of 4.1

# %% [markdown]
# ### Lets Look at the categories of behind the scenes roles

# %%
final.groupby('category').mean()
# Out:
#                      ordering   start_year  runtime_minutes  averagerating  \
# category
# actor                3.141918  2014.609077        93.386378       6.096369
# actress              3.154383  2014.729242        93.984132       5.991169
# archive_footage      3.528273  2014.390686        90.582524       7.056962
# archive_sound        3.437500  2014.437500        84.687500       7.016667
# cinematographer      7.147657  2014.540972        87.094161       6.412092
# composer             6.905156  2014.472172        89.195393       6.330604
# director             4.005519  2014.582699        86.733112       6.349827
# editor               7.405282  2014.436482        85.447614       6.499966
# producer             6.542418  2014.737461        92.428086       6.257795
# production_designer  8.970340  2014.633949        92.996967       6.089415
# self                 3.247616  2014.452739        80.517521       7.310987
# ...

# %%
#Sorting for top directors
director_rating = final[final.category == 'director']

director_rating = director_rating.groupby('primary_name').mean().sort_values(['averagerating','numvotes'], ascending = False)
director_rating = director_rating[(director_rating.start_year < 2019.0) & (director_rating.start_year >= 2010.0) & (director_rating.numvotes > 4110)]
top_director = director_rating.head(5)
top_director
# Out:
#                         ordering  start_year  runtime_minutes  averagerating  \
# primary_name
# Bharatha Hettiarachchi       6.0      2017.0            113.0            9.5
# Chathra Weeraman             5.0      2017.0            113.0            9.5
# Amudhavan Karuppiah          6.0      2018.0            147.0            9.4
# Anjana Krishnakumar          7.0      2018.0            147.0            9.4
# Amitabh Reza Chowdhury       5.0      2016.0            147.0            9.3
#
#                         numvotes  birth_year  death_year
# primary_name
# Bharatha Hettiarachchi    6509.0         NaN         NaN
# Chathra Weeraman          6509.0         NaN         NaN
# Amudhavan Karuppiah       9629.0         NaN         NaN
# Anjana Krishnakumar       9629.0         NaN         NaN
# Amitabh Reza Chowdhury   18470.0         NaN         NaN

# %%
#Sorting for top producer
producer_rating = final[final.category == 'producer']

producer_rating = producer_rating.groupby('primary_name').mean().sort_values(['averagerating','numvotes'], ascending = False)
producer_rating = producer_rating[(producer_rating.start_year < 2019.0) & (producer_rating.start_year >= 2010.0)& (producer_rating.numvotes > 4110)]
top_producer = producer_rating.head(5)
top_producer
# Out:
#                      ordering  start_year  runtime_minutes  averagerating  \
# primary_name
# Thusitha Wijayasena       8.0      2017.0            113.0            9.5
# Ziauddin Adil             9.0      2016.0            147.0            9.3
# Oner Isik                 3.0      2013.0            139.0            9.2
# Emir Hakim                9.0      2018.0            102.0            9.1
# Tamara Rosenberg         10.0      2016.0            467.0            8.9
#
#                      numvotes  birth_year  death_year
# primary_name
# Thusitha Wijayasena    6509.0         NaN         NaN
# Ziauddin Adil         18470.0         NaN         NaN
# Oner Isik             41560.0         NaN         NaN
# Emir Hakim             4162.0         NaN         NaN
# Tamara Rosenberg      14946.0         NaN         NaN

# %%
#Sorting for top composer
composer_rating = final[final.category == 'composer']

composer_rating = composer_rating.groupby('primary_name').mean().sort_values(['averagerating','numvotes'], ascending = False)
composer_rating = composer_rating[(composer_rating.start_year < 2019.0) & (composer_rating.start_year >= 2010.0) & (composer_rating.numvotes > 4110)]
top_composer = composer_rating.head(5)
top_composer
# Out:
#                    ordering  start_year  runtime_minutes  averagerating  \
# primary_name
# Milinda Tennakone       9.0      2017.0            113.0            9.5
# Sertac Özgümüs          5.0      2013.0            139.0            9.2
# Vedanth                 9.0      2016.0            130.0            8.8
# Mana Tahan              8.0      2014.0            103.0            8.3
# Seri Banang             7.0      2014.0            103.0            8.3
#
#                    numvotes  birth_year  death_year
# primary_name
# Milinda Tennakone    6509.0         NaN         NaN
# Sertac Özgümüs      41560.0         NaN         NaN
# Vedanth              8277.0         NaN         NaN
# Mana Tahan          10162.0         NaN         NaN
# Seri Banang         10162.0         NaN         NaN

# %%
#Sorting for top writer
writer_rating = final[final.category == 'writer']

writer_rating = writer_rating.groupby('primary_name').mean().sort_values(['averagerating','numvotes'], ascending = False)
writer_rating = writer_rating[(writer_rating.start_year < 2019.0) & (writer_rating.start_year >= 2010.0) & (writer_rating.numvotes > 4110)]
top_writer = writer_rating.head(5)
top_writer
# Out:
#                         ordering  start_year  runtime_minutes  averagerating  \
# primary_name
# Saman Weeraman               7.0      2017.0            113.0            9.5
# Adnan Adib Khan              8.0      2016.0            147.0            9.3
# Anam Biswas                  7.0      2016.0            147.0            9.3
# Syed Gaosul Alam Shaon       6.0      2016.0            147.0            9.3
# Kiran Yadnyopavit            7.0      2016.0            166.0            9.2
#
#                         numvotes  birth_year  death_year
# primary_name
# Saman Weeraman            6509.0      1950.0         NaN
# Adnan Adib Khan          18470.0         NaN         NaN
# Anam Biswas              18470.0         NaN         NaN
# Syed Gaosul Alam Shaon   18470.0         NaN         NaN
# Kiran Yadnyopavit         4297.0         NaN         NaN

# %%
# John Williams average rating as a composer
final[(final.primary_name == 'John Williams') & (final.category == 'composer')].averagerating.mean()
# Out:
# 6.8500000000000005

# %%
# Plot the 4 Behind the Scenes Reccomendations

fig, axs = plt.subplots(2, 2,figsize=(30,30))
fig.suptitle('Top 5 Rated Behind The Scenes Roles \n With More Than The Average Number of Reviews \nOn a scale of 1 -10', fontsize=30)

axs[0, 0].bar(top_director.index, top_director.averagerating.values, color ='green')
axs[0, 0].set_title('Top 5 Rated Directors', fontsize=30)
axs[0, 0].set_xlabel('Director', fontsize=25)
axs[0, 0].set_ylabel('Rating ', fontsize=25)
axs[0, 0].set_xticklabels(top_director.index, rotation=15, ha="right",fontsize=15)

axs[0, 1].bar(top_producer.index, top_producer.averagerating.values, color ='green')
axs[0, 1].set_title('Top 5 Rated Producers', fontsize=30)
axs[0, 1].set_xlabel('Producer', fontsize=25)
axs[0, 1].set_ylabel('Rating', fontsize=25)
axs[0, 1].set_xticklabels(top_producer.index, rotation=15, ha="right",fontsize=15)


axs[1, 0].bar(top_composer.index, top_composer.averagerating.values, color ='green')
axs[1, 0].set_title('Top 5 Rated Composers', fontsize=30)
axs[1, 0].set_xlabel('Composer', fontsize=25)
axs[1, 0].set_ylabel('Rating ', fontsize=25)
axs[1, 0].set_xticklabels(top_composer.index, rotation=15, ha="right",fontsize=15)
                     
axs[1, 1].bar(top_writer.index, top_writer.averagerating.values, color ='green')
axs[1, 1].set_title('Top 5 Rated Writers', fontsize=30)
axs[1, 1].set_xlabel('Writer', fontsize=25)
axs[1, 1].set_ylabel('Rating ', fontsize=25)
axs[1, 1].set_xticklabels(top_writer.index, rotation=15, ha="right",fontsize=15)

plt.savefig('Top5s.png')
plt.show()
